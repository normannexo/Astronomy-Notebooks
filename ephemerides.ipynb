# %% [markdown]
# ## Calculating Ephemerides
#
# Some experiments with pyephem and astropy

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ephem
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import datetime
import seaborn as sns
from geopy.geocoders import Nominatim
import math

sns.set()
sns.set_style('whitegrid')

# %%
geolocator = Nominatim(user_agent="astronomy_notebook")
sun = ephem.Sun()
rigel = ephem.star("Rigel")

# %%
cities = ["Cologne", "Stockholm", "London", "Rome", "Bergen", "Cape Town"]
city_geocodes = [geolocator.geocode(city) for city in cities]
obs = ephem.Observer()
city_geocodes
# Out:
# [Location(Köln, Nordrhein-Westfalen, Deutschland, (50.938361, 6.959974, 0.0)),
#  Location(Stockholm, Stockholms kommun, Stockholms län, 111 29, Sverige, (59.3251172, 18.0710935, 0.0)),
#  Location(London, Greater London, England, United Kingdom, (51.5073219, -0.1276474, 0.0)),
#  Location(Roma, Roma Capitale, Lazio, Italia, (41.8989553, 12.4730842, 0.0)),
#  Location(Bergen, Vestland, Norge, (60.3943055, 5.3259192, 0.0)),
#  Location(Cape Town, City of Cape Town, Western Cape, 8001, South Africa, (-33.928992, 18.417396, 0.0))]

# %%
hour_interval = 1
days = 1

pos_list = []



geocode = city_geocodes[0]

obs.lat = str(geocode.latitude)
obs.lon = str(geocode.longitude)
obs.date = '2021/03/15 0:00'
print([obs.lat, obs.lon])
for i in range(int(24*days//hour_interval)):
    obs.date = obs.date + (hour_interval*ephem.hour)
    sun.compute(obs)
    pos_list.append({'time':pd.to_datetime(str(obs.date)), 'alt':math.degrees(sun.alt), 'az':math.degrees(sun.az), 'next_rising':str(obs.next_rising(sun))})
pos_list

df = pd.DataFrame(pos_list)
fig, ax = plt.subplots(1, 1, figsize=(20,8))
ax = sns.lineplot(data=df, x='time',y='alt')
date_form = DateFormatter("%m-%d, %H:%M")
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
ax.xaxis.set_tick_params(rotation=90)
plt.title("Altitude sun - " + geocode.address, fontsize=20)
df
# Out:
# [0.8890421150194713, 0.12147446215319982]
#                   time        alt          az         next_rising
# 0  2021-03-15 01:00:00 -38.429636   25.487153  2021/3/15 05:45:31
# 1  2021-03-15 02:00:00 -33.102713   42.796975  2021/3/15 05:45:31
# 2  2021-03-15 03:00:00 -25.813319   57.873928  2021/3/15 05:45:31
# 3  2021-03-15 04:00:00 -17.276280   71.146672  2021/3/15 05:45:31
# 4  2021-03-15 05:00:00  -8.054281   83.282464  2021/3/15 05:45:31
# 5  2021-03-15 06:00:00   1.711643   94.956281  2021/3/16 05:43:18
# 6  2021-03-15 07:00:00  10.753644  106.810594  2021/3/16 05:43:18
# 7  2021-03-15 08:00:00  19.413310  119.474229  2021/3/16 05:43:18
# 8  2021-03-15 09:00:00  27.007020  133.550375  2021/3/16 05:43:18
# 9  2021-03-15 10:00:00  32.901049  149.482365  2021/3/16 05:43:18
# 10 2021-03-15 11:00:00  36.407012  167.229204  2021/3/16 05:43:18
# 11 2021-03-15 12:00:00  36.987616  185.941163  2021/3/16 05:43:18
# 12 2021-03-15 13:00:00  34.542835  204.198190  2021/3/16 05:43:18
# 13 2021-03-15 14:00:00  29.475125  220.862705  2021/3/16 05:43:18
# 14 2021-03-15 15:00:00  22.450555  235.611036  2021/3/16 05:43:18
# 15 2021-03-15 16:00:00  14.135614  248.751719  2021/3/16 05:43:18
# 16 2021-03-15 17:00:00   5.134611  260.853831  2021/3/16 05:43:18
# 17 2021-03-15 18:00:00  -2.989021  272.542552  2021/3/16 05:43:18
# 18 2021-03-15 19:00:00 -13.753553  284.452326  2021/3/16 05:43:18
# 19 2021-03-15 20:00:00 -22.563016  297.242210  2021/3/16 05:43:18
# 20 2021-03-15 21:00:00 -30.342412  311.587493  2021/3/16 05:43:18
# 21 2021-03-15 22:00:00 -36.430839  328.034588  2021/3/16 05:43:18
# 22 2021-03-15 23:00:00 -40.067857  346.599234  2021/3/16 05:43:18
# 23 2021-03-16 00:00:00 -40.638205    6.303562  2021/3/16 05:43:18

# %%
hour_interval = 24
days = 365

pos_list = []


obs.lat = str(geocode.latitude)
obs.lon = str(geocode.longitude)
obs.date = '2020/12/21 12:00'
print([obs.lat, obs.lon])
for i in range(int(24*days//hour_interval)):
    obs.date = obs.date + (hour_interval*ephem.hour)
    sun.compute(obs)
    pos_list.append({'time':pd.to_datetime(str(obs.date)), 'alt':math.degrees(sun.alt), 'az':math.degrees(sun.az), 'next_setting':pd.to_datetime(str(obs.next_setting(sun))), 'previous_rising':pd.to_datetime(str(obs.previous_rising(sun)))})
pos_list

df = pd.DataFrame(pos_list)
df['sun_hours'] = (df.next_setting - df.previous_rising).dt.seconds / 3600
df
# Out:
# [0.8890421150194713, 0.12147446215319982]
#                    time        alt          az        next_setting  \
# 0   2020-12-22 12:00:00  15.408555  186.905955 2020-12-22 15:29:08
# 1   2020-12-23 12:00:00  15.430217  186.789104 2020-12-23 15:29:44
# 2   2020-12-24 12:00:00  15.459508  186.673059 2020-12-24 15:30:22
# 3   2020-12-25 12:00:00  15.496412  186.557916 2020-12-25 15:31:04
# 4   2020-12-26 12:00:00  15.540880  186.443769 2020-12-26 15:31:48
# ..                  ...        ...         ...                 ...
# 360 2021-12-17 12:00:00  15.419400  187.531532 2021-12-17 15:26:54
# 361 2021-12-18 12:00:00  15.400951  187.412864 2021-12-18 15:27:12
# 362 2021-12-19 12:00:00  15.390137  187.294401 2021-12-19 15:27:34
# 363 2021-12-20 12:00:00  15.386963  187.176253 2021-12-20 15:27:59
# 364 2021-12-21 12:00:00  15.391427  187.058473 2021-12-21 15:28:27
#
#         previous_rising  sun_hours
# 0   2020-12-22 07:32:47   7.939167
# 1   2020-12-23 07:33:12   7.942222
# 2   2020-12-24 07:33:34   7.946667
# 3   2020-12-25 07:33:53   7.953056
# 4   2020-12-26 07:34:09   7.960833
# ..                  ...        ...
# 360 2021-12-17 07:29:42   7.953333
# 361 2021-12-18 07:30:23   7.946944
# 362 2021-12-19 07:31:02   7.942222
# 363 2021-12-20 07:31:37   7.939444
# 364 2021-12-21 07:32:09   7.938333
#
# [365 rows x 6 columns]

# %%
hour_interval = 24
days = 365

pos_list = []

for code in city_geocodes:
    obs.lat = str(code.latitude)
    obs.lon = str(code.longitude)
    obs.date = '2020/12/21 12:00'
    for i in range(int(24*days//hour_interval)):
        obs.date = obs.date + (hour_interval*ephem.hour)
        sun.compute(obs)
        pos_list.append({'time':pd.to_datetime(str(obs.date)), 'alt':math.degrees(sun.alt), 'az':math.degrees(sun.az), 'next_setting':pd.to_datetime(str(obs.next_setting(sun))), 'previous_rising':pd.to_datetime(str(obs.previous_rising(sun))), 'name':code.address})


df = pd.DataFrame(pos_list)
df['sun_hours'] = (df.next_setting - df.previous_rising).dt.seconds / 3600
df
# Out:
#                     time        alt          az        next_setting  \
# 0    2020-12-22 12:00:00  15.408555  186.905955 2020-12-22 15:29:08
# 1    2020-12-23 12:00:00  15.430217  186.789104 2020-12-23 15:29:44
# 2    2020-12-24 12:00:00  15.459508  186.673059 2020-12-24 15:30:22
# 3    2020-12-25 12:00:00  15.496412  186.557916 2020-12-25 15:31:04
# 4    2020-12-26 12:00:00  15.540880  186.443769 2020-12-26 15:31:48
# ...                  ...        ...         ...                 ...
# 2185 2021-12-17 12:00:00  70.047688  296.866768 2021-12-17 17:55:10
# 2186 2021-12-18 12:00:00  70.155141  296.994274 2021-12-18 17:55:44
# 2187 2021-12-19 12:00:00  70.258324  297.142326 2021-12-19 17:56:18
# 2188 2021-12-20 12:00:00  70.357109  297.311031 2021-12-20 17:56:50
# 2189 2021-12-21 12:00:00  70.451352  297.500364 2021-12-21 17:57:20
#
#          previous_rising                                               name  \
# 0    2020-12-22 07:32:47             Köln, Nordrhein-Westfalen, Deutschland
# 1    2020-12-23 07:33:12             Köln, Nordrhein-Westfalen, Deutschland
# 2    2020-12-24 07:33:34             Köln, Nordrhein-Westfalen, Deutschland
# 3    2020-12-25 07:33:53             Köln, Nordrhein-Westfalen, Deutschland
# 4    2020-12-26 07:34:09             Köln, Nordrhein-Westfalen, Deutschland
# ...                  ...                                                ...
# 2185 2021-12-17 03:29:53  Cape Town, City of Cape Town, Western Cape, 80...
# 2186 2021-12-18 03:30:16  Cape Town, City of Cape Town, Western Cape, 80...
# 2187 2021-12-19 03:30:41  Cape Town, City of Cape Town, Western Cape, 80...
# 2188 2021-12-20 03:31:07  Cape Town, City of Cape Town, Western Cape, 80...
# 2189 2021-12-21 03:31:35  Cape Town, City of Cape Town, Western Cape, 80...
#
#       sun_hours
# 0      7.939167
# 1      7.942222
# 2      7.946667
# 3      7.953056
# 4      7.960833
# ...         ...
# 2185  14.421389
# 2186  14.424444
# 2187  14.426944
# 2188  14.428611
# 2189  14.429167
#
# [2190 rows x 7 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(20,8))
ax = sns.lineplot(data=df, x='time', y='sun_hours', hue='name')
legend_labels =ax.get_legend_handles_labels()
ax.legend([label.split(',')[0].strip() for label in legend_labels[1]])
plt.title("Sun hours for different cities over one year", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Sun hours for different cities over one year')

# %% [markdown]
# ### Astropy

# %%
import astropy.units as u 
from astropy.time import Time
from astropy.coordinates import SkyCoord, EarthLocation, AltAz

# %%
m31 = SkyCoord.from_name('M31')

# %%
cologne = city_geocodes[0]
cologne
# Out:
# Location(Köln, Nordrhein-Westfalen, Deutschland, (50.938361, 6.959974, 0.0))

# %%
location = EarthLocation(lat=cologne.latitude*u.deg, lon =cologne.longitude*u.deg, height=0*u.m)
utcoffset= 1*u.hour
time = Time('2021-03-20 20:00:00') - utcoffset

# %%
m31altaz = m31.transform_to(AltAz(obstime=time, location=location))
print("{0.alt:.2}".format(m31altaz))
# Out:
# 2.6e+01 deg

# %%
from astropy.coordinates import get_sun
noon = Time('2021-03-20 12:00:00') - utcoffset
delta_noon = np.linspace(-12, 12, 1000)*u.hour
times = noon + delta_noon
frames = AltAz(obstime=times, location=location)

# %%
sunaltazs = get_sun(times).transform_to(frames)

# %%
sns.lineplot(x=delta_noon, y=sunaltazs.alt)
# Out:
# <AxesSubplot:>
